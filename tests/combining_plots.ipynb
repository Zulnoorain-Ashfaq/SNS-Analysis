# %%
import matplotlib.pyplot as plt

from src.analysis import Analysis
import seaborn as sns

# %%
data = sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
analysis = Analysis(data)

# %%
sepal_length_plot = analysis.make_plot('line','species','sepal_length',agg=['max','min'],create_copy=True)

# %%
petal_length_plot = analysis.make_plot('line','species','petal_length', agg=['max','min'],create_copy=True)

# %%
analysis.combine_plot([sepal_length_plot,petal_length_plot])
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
data = sns.load_dataset('car_crashes')
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
analysis = Analysis(data)

# %%
plot_1 = analysis.make_plot('reg','speeding','alcohol',create_copy=True)

# %%
plot_2 = analysis.make_plot('reg','speeding','not_distracted', create_copy=True)

# %%
plot_3 = analysis.make_plot('line','speeding','no_previous', create_copy=True)

# %%
plot_4 = analysis.make_plot('scatter','speeding', 'not_distracted', create_copy=True)

# %%
analysis.combine_plot([plot_1, plot_2, plot_3,plot_4])
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
